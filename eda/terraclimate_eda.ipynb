# %% [markdown]
# ## Exploratory Data Analysis for extracted Terraclimate features

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tc_df = pd.read_csv("../data/terraclimate_features_training.csv")
tc_df
# Out:
#        Latitude  Longitude Sample Date        pet
# 0    -28.760833  17.730278  02-01-2011  174.20000
# 1    -26.861111  28.884722  03-01-2011  124.10000
# 2    -26.450000  28.085833  03-01-2011  127.50000
# 3    -27.671111  27.236944  03-01-2011  129.70000
# 4    -27.356667  27.286389  03-01-2011  129.20000
# ...         ...        ...         ...        ...
# 9314 -27.527500  30.858056  23-12-2015  166.30000
# 9315 -26.861111  28.884722  23-12-2015  182.40001
# 9316 -26.984722  26.632278  23-12-2015  207.80000
# 9317 -27.935000  26.126667  23-12-2015  222.80000
# 9318 -29.744167  29.905833  31-12-2015  161.00000
#
# [9319 rows x 4 columns]

# %%
tc_df.head()
# Out:
#     Latitude  Longitude Sample Date    pet
# 0 -28.760833  17.730278  02-01-2011  174.2
# 1 -26.861111  28.884722  03-01-2011  124.1
# 2 -26.450000  28.085833  03-01-2011  127.5
# 3 -27.671111  27.236944  03-01-2011  129.7
# 4 -27.356667  27.286389  03-01-2011  129.2

# %%
tc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9319 entries, 0 to 9318
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Latitude     9319 non-null   float64
#  1   Longitude    9319 non-null   float64
#  2   Sample Date  9319 non-null   object
#  3   pet          9319 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 291.3+ KB

# %% [markdown]
# No missing values, thats great.

# %%
tc_df.describe(include='all')
# Out:
#            Latitude    Longitude Sample Date          pet
# count   9319.000000  9319.000000        9319  9319.000000
# unique          NaN          NaN        1364          NaN
# top             NaN          NaN  08-01-2014          NaN
# freq            NaN          NaN          23          NaN
# mean     -28.474988    26.868414         NaN   175.166082
# std        2.760282     3.535164         NaN    29.469867
# min      -34.405833    17.730278         NaN    52.700000
# 25%      -30.160091    26.126667         NaN   156.100000
# 50%      -28.058889    27.409060         NaN   172.500000
# 75%      -26.861111    29.245556         NaN   193.100000
# max      -22.225556    32.325000         NaN   270.800020

# %%
plt.hist(tc_df['pet'])
plt.xlabel('PET')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Distribution looks fairly normal here, still use scaling when training SVM. CatBoost and TabPFN dont require scaling.
