# %% [markdown]
# ## Extraction of Data from jrc Dataset (GEE) ##

# %% [markdown]
# Following same extraction process in all datasets

# %%
# Import Google Earth Engine API and Initialize it. 
import ee
import pandas as pd

ee.Authenticate()
ee.Initialize(project="ey-data-and-ai-challenge")

# %%
# Read coordinates from water quality training dataset, drop given features and date since iSDA datasets are static, i.e. not date dependent.

wq_df = pd.read_csv('../data/water_quality_training_dataset.csv')
wq_df = wq_df.drop(columns=['Total Alkalinity', 'Electrical Conductance', 'Dissolved Reactive Phosphorus'])
wq_df['id'] = wq_df.index
wq_df.head()
# Out:
#     Latitude  Longitude Sample Date  id
# 0 -28.760833  17.730278  02-01-2011   0
# 1 -26.861111  28.884722  03-01-2011   1
# 2 -26.450000  28.085833  03-01-2011   2
# 3 -27.671111  27.236944  03-01-2011   3
# 4 -27.356667  27.286389  03-01-2011   4

# %%
# Convert Coordintaes to ee.Features

features = []

for index, row in wq_df.iterrows():
    feat = ee.Feature(
        ee.Geometry.Point([row['Longitude'], row['Latitude']]).buffer(100), #add a 100m buffer in case of inexact coordinates
        {'id': row['id']}
    )
    features.append(feat)

# %%
# Read hydrosheds dataset as Earth Engine image
reducer = ee.Reducer.mean().setOutputs(['flow_accumulation'])
hydro_img = ee.Image("WWF/HydroSHEDS/15ACC").select('b1').rename('flow_accumulation') # select wanted band and rename

# %%
fc = ee.FeatureCollection(features) # convert features into feature collection

# %%
# Run geospatial data query using reduceRegions()

hydro_collection = hydro_img.reduceRegions(collection=fc, reducer=reducer, scale = 464)

# %%
# Process data and export to Google Drive

task = ee.batch.Export.table.toDrive(
    collection=hydro_collection,
    description="hydro_csv_export",
    fileNamePrefix= "hydrosheds_features_training",
    fileFormat='CSV'
)
task.start()

# %%
hydro_df = pd.read_csv("../data/hydrosheds_features_training.csv")

# Drop irrelevant columns
hydro_df.drop(columns=[".geo", "system:index"], inplace=True)

hydro_df = hydro_df.merge(wq_df, on='id', how='left')
hydro_df.drop(columns=['id'], inplace=True)
hydro_df
# Out:
#       flow_accumulation   Latitude  Longitude Sample Date
# 0          4.131443e+06 -28.760833  17.730278  02-01-2011
# 1          1.162031e+04 -26.861111  28.884722  03-01-2011
# 2          1.000000e+00 -26.450000  28.085833  03-01-2011
# 3          1.878500e+04 -27.671111  27.236944  03-01-2011
# 4          4.778000e+03 -27.356667  27.286389  03-01-2011
# ...                 ...        ...        ...         ...
# 9314       5.009590e+03 -27.527500  30.858056  23-12-2015
# 9315       1.162031e+04 -26.861111  28.884722  23-12-2015
# 9316       3.094600e+04 -26.984722  26.632278  23-12-2015
# 9317       1.000000e+00 -27.935000  26.126667  23-12-2015
# 9318       4.120000e+02 -29.744167  29.905833  31-12-2015
#
# [9319 rows x 4 columns]

# %%
hydro_df.to_csv("../data/hydrosheds_features_training.csv")

# %% [markdown]
# # Repeat for Validation Set

# %%
val_df = pd.read_csv("../data/submission_template.csv")
val_df['id'] = val_df.index
val_df
# Out:
#       Latitude  Longitude Sample Date  Total Alkalinity  \
# 0   -32.043333  27.822778  01-09-2014               NaN
# 1   -33.329167  26.077500  16-09-2015               NaN
# 2   -32.991639  27.640028  07-05-2015               NaN
# 3   -34.096389  24.439167  07-02-2012               NaN
# 4   -32.000556  28.581667  01-10-2014               NaN
# ..         ...        ...         ...               ...
# 195 -33.771111  25.386667  06-12-2012               NaN
# 196 -33.185361  27.390750  04-09-2014               NaN
# 197 -32.043333  27.822778  28-09-2015               NaN
# 198 -33.001667  25.161389  08-01-2015               NaN
# 199 -33.237780  26.994720  27-03-2013               NaN
#
#      Electrical Conductance  Dissolved Reactive Phosphorus   id
# 0                       NaN                            NaN    0
# 1                       NaN                            NaN    1
# 2                       NaN                            NaN    2
# 3                       NaN                            NaN    3
# 4                       NaN                            NaN    4
# ..                      ...                            ...  ...
# 195                     NaN                            NaN  195
# 196                     NaN                            NaN  196
# 197                     NaN                            NaN  197
# 198                     NaN                            NaN  198
# 199                     NaN                            NaN  199
#
# [200 rows x 7 columns]

# %%
features_val = []

for index, row in val_df.iterrows():
    feat_val = ee.Feature(
        ee.Geometry.Point([row['Longitude'], row['Latitude']]).buffer(100), #add a 100m buffer in case of inexact coordinates
        {'id': row['id']}
    )
    features_val.append(feat_val)

# %%
fc_val = ee.FeatureCollection(features_val)
hydro_collection_val = hydro_img.reduceRegions(collection=fc_val, reducer=reducer, scale = 464)

# %%
task_val = ee.batch.Export.table.toDrive(
    collection=hydro_collection_val,
    description="hydrosheds_val_csv_export",
    fileNamePrefix= "hydrosheds_features_validation",
    fileFormat='CSV'
)
task_val.start()

# %%
hydro_val_df = pd.read_csv("../data/hydrosheds_features_validation.csv")

# Drop irrelevant columns
hydro_val_df.drop(columns=[".geo", "system:index"], inplace=True)

hydro_val_df = hydro_val_df.merge(val_df, on='id', how='left')
hydro_val_df.drop(columns=['id'], inplace=True)
hydro_val_df
# Out:
#      flow_accumulation   Latitude  Longitude Sample Date  Total Alkalinity  \
# 0         13004.285714 -32.043333  27.822778  01-09-2014               NaN
# 1          8089.000000 -33.329167  26.077500  16-09-2015               NaN
# 2          5072.666667 -32.991639  27.640028  07-05-2015               NaN
# 3           787.063830 -34.096389  24.439167  07-02-2012               NaN
# 4         14141.365854 -32.000556  28.581667  01-10-2014               NaN
# ..                 ...        ...        ...         ...               ...
# 195        5131.000000 -33.771111  25.386667  06-12-2012               NaN
# 196       14092.000000 -33.185361  27.390750  04-09-2014               NaN
# 197       13004.285714 -32.043333  27.822778  28-09-2015               NaN
# 198           1.000000 -33.001667  25.161389  08-01-2015               NaN
# 199      163051.000000 -33.237780  26.994720  27-03-2013               NaN
#
#      Electrical Conductance  Dissolved Reactive Phosphorus
# 0                       NaN                            NaN
# 1                       NaN                            NaN
# 2                       NaN                            NaN
# 3                       NaN                            NaN
# 4                       NaN                            NaN
# ..                      ...                            ...
# 195                     NaN                            NaN
# 196                     NaN                            NaN
# 197                     NaN                            NaN
# 198                     NaN                            NaN
# 199                     NaN                            NaN
#
# [200 rows x 7 columns]

# %%
hydro_val_df.to_csv("../data/hydrosheds_features_validation.csv")
